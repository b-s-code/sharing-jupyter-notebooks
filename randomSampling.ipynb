# %% [markdown]
# Random Sampling
# ===
#
# URL of numpy docs:
# `https://numpy.org/doc/1.16/reference/routines.random.html`

# %% [markdown]
# Importing numpy
# ---

# %%
import numpy.random as npr

# %% [markdown]
# Creating an array of specified shape filled with random values
# ---

# %% [markdown]
# Each random value will lie in the open interval $(0,1)$.

# %%
npr.rand(2, 3, 2)
# Out:
# array([[[0.21282413, 0.9676692 ],
#         [0.38758667, 0.90674388],
#         [0.73469305, 0.5875166 ]],
#
#        [[0.85490092, 0.69175148],
#         [0.4001289 , 0.88128107],
#         [0.21360312, 0.79189552]]])

# %% [markdown]
# Providing no argument to the numpy.random() function returns a single float.

# %%
npr.rand()
# Out:
# 0.5754299166364293
